# %% [markdown]
# # Description
#
# This analysis takes inspiration from the paper [Unbiased determination of DVCS Compton Form Factors](https://arxiv.org/abs/1905.02089).

# %% [markdown]
# # Imports

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
# Out:
# 2.2.0

# %%
class DvcsData(object):
    def __init__(self, df):
        self.X = df.loc[:, ['phi_x', 'k', 'QQ', 'x_b', 't', 'F1', 'F2', 'ReH', 'ReE', 'ReHtilde', 'dvcs']]
        self.XnoCFF = df.loc[:, ['phi_x', 'k', 'QQ', 'x_b', 't', 'F1', 'F2', 'dvcs']]
        self.y = df.loc[:, 'F']
        self.Kinematics = df.loc[:, ['k', 'QQ', 'x_b', 't']]
        self.erry = df.loc[:, 'errF']
        
    def __len__(self):
        return len(self.X)
    
    def getSet(self, setNum, itemsInSet=36):
        pd.options.mode.chained_assignment = None
        subX = self.X.loc[setNum*itemsInSet:(setNum+1)*itemsInSet-1, :]
        subX['F'] = self.y.loc[setNum*itemsInSet:(setNum+1)*itemsInSet-1]
        subX['errF'] = self.erry.loc[setNum*itemsInSet:(setNum+1)*itemsInSet-1]
        pd.options.mode.chained_assignment = 'warn'
        return DvcsData(subX)
    
    def sampleY(self):
        return np.random.normal(self.y, self.erry)
    
    def sampleWeights(self):
        return 1/self.erry
    
    def getAllKins(self, itemsInSets=36):
        return self.Kinematics.iloc[np.array(range(len(df)//itemsInSets))*itemsInSets, :]

# %%
df = pd.read_csv("dvcs_xs_newsets_genCFFs.csv")
fits = pd.read_csv("fits.csv")
data = DvcsData(df)

# %%
valid_y = fits.sample(2)
train_y = fits.drop(valid_y.index)
valid_x = data.getAllKins().iloc[valid_y.index, :]
train_x = data.getAllKins().drop(valid_x.index)

# %%
kinematics = tf.keras.Input(shape=(4))
x = tf.keras.layers.Dense(10, activation="tanh")(kinematics)
outputs = tf.keras.layers.Dense(3)(x)

globalModel = tf.keras.Model(inputs=kinematics, outputs=outputs, name="GlobalModel")

# %%
tf.keras.utils.plot_model(globalModel, "cffs.png", show_shapes=True)

# %%
globalModel.compile(optimizer=tf.keras.optimizers.Adam(1), loss=tf.keras.losses.MeanSquaredError())

# %%
globalModel(valid_x)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[ 5.1054120e-01, -1.9755960e-04, -5.1804924e-01],
#        [ 5.1641965e-01,  2.5556028e-02, -4.8931825e-01]], dtype=float32)>

# %%
valid_x.iloc[0, :]
# Out:
# k      6.750000
# QQ     1.950720
# x_b    0.360829
# t     -0.278690
# Name: 324, dtype: float64

# %%
valid_x.iloc[1, :]
# Out:
# k      4.750000
# QQ     2.179550
# x_b    0.385579
# t     -0.283318
# Name: 72, dtype: float64

# %%
globalModel(valid_x.iloc[[1], :])
# Out:
# <tf.Tensor: shape=(1, 3), dtype=float32, numpy=array([[  9.75326  , -48.57067  ,   5.6907144]], dtype=float32)>

# %%
globalModel(valid_x.iloc[[0], :])
# Out:
# <tf.Tensor: shape=(1, 3), dtype=float32, numpy=array([[  9.75326  , -48.57067  ,   5.6907144]], dtype=float32)>

# %%
globalModel(train_x)
# Out:
# <tf.Tensor: shape=(13, 3), dtype=float32, numpy=
# array([[  9.753261, -48.570675,   5.690714],
#        [  9.753261, -48.570675,   5.690714],
#        [  9.753261, -48.570675,   5.690714],
#        [  9.753261, -48.570675,   5.690714],
#        [  9.753261, -48.570675,   5.690714],
#        [  9.753261, -48.570675,   5.690714],
#        [  9.753261, -48.570675,   5.690714],
#        [  9.753261, -48.570675,   5.690714],
#        [  9.753261, -48.570675,   5.690714],
#        [  9.753261, -48.570675,   5.690714],
#        [  9.753261, -48.570675,   5.690714],
#        [  9.753261, -48.570675,   5.690714],
#        [  9.753261, -48.570675,   5.690714]], dtype=float32)>

# %%
train_y.mean()
# Out:
# ReH          9.753328
# ReE        -48.570673
# ReHtilde     5.690670
# dtype: float64

# %% [markdown]
# ## ReHModel w Noise

# %%
fits
# Out:
#           ReH        ReE  ReHTilde    ReHerr     ReEerr  ReHTilderr
# 0   13.878755 -57.383343  6.799729  1.116576   5.740966    0.630739
# 1   11.719817 -47.746209  7.488039  2.559194  13.450243    1.250604
# 2    6.540862 -43.195876  4.484700  2.028538  11.627438    0.742568
# 3    8.982135 -54.485782  4.516039  2.945940  14.852145    1.118831
# 4   11.693827 -47.947156  7.354355  1.211438   6.219190    0.676689
# 5    6.719193 -44.275317  4.268059  1.419693   8.062980    0.486565
# 6   10.171167 -42.854521  6.951665  3.233800  18.385221    1.550622
# 7    8.872783 -53.917385  4.881407  2.489644  12.542550    1.702062
# 8   11.758800 -48.342613  7.245830  0.742077   3.826029    0.775337
# 9    8.099759 -53.588436  3.157422  0.978644   6.026498    0.439592
# 10   6.787341 -44.670218  4.209940  1.257024   7.136178    0.620303
# 11  10.609554 -45.477080  6.527541  2.095339  11.700650    0.947834
# 12   8.016455 -53.110773  3.215409  0.949557   5.858383    0.514110
# 13   6.809949 -44.792840  4.211061  1.247311   7.090771    0.777981
# 14  10.773485 -46.415510  6.309638  1.637597   9.126394    0.950473

# %%
valid_y = fits["ReH"].sample(5)
valid_x = data.getAllKins().reset_index().loc[valid_y.index].drop(["index"], axis='columns')

# %%
train_x = data.getAllKins().reset_index().drop(["index"], axis='columns').drop(valid_x.index, axis='rows')
train_x = pd.DataFrame(np.repeat(train_x.values, 20, axis=0))

train_y = np.array([])
for row in range(15):
    if not row in valid_x.index:
        train_y = np.concatenate((train_y, np.random.normal(fits.loc[row, "ReH"], fits.loc[row, "ReHerr"], 20)))

# %%
kinematics = tf.keras.Input(shape=(4))
x = tf.keras.layers.Dense(1, activation='relu')(kinematics)
outputs = tf.keras.layers.Dense(1)(x)

ReHModel = tf.keras.Model(inputs=kinematics, outputs=outputs, name="GlobalModel")

# %%
tf.keras.utils.plot_model(ReHModel, "cffs.png", show_shapes=True)

# %%
ReHModel.compile(optimizer=tf.keras.optimizers.Adam(.1), loss=tf.keras.losses.MeanSquaredError())

# %%
train_x
# Out:
#         0        1         2         3
# 0    3.75  1.74013  0.435095 -0.380868
# 1    3.75  1.74013  0.435095 -0.380868
# 2    3.75  1.74013  0.435095 -0.380868
# 3    3.75  1.74013  0.435095 -0.380868
# 4    3.75  1.74013  0.435095 -0.380868
# ..    ...      ...       ...       ...
# 195  7.75  1.95072  0.360829 -0.278690
# 196  7.75  1.95072  0.360829 -0.278690
# 197  7.75  1.95072  0.360829 -0.278690
# 198  7.75  1.95072  0.360829 -0.278690
# 199  7.75  1.95072  0.360829 -0.278690
#
# [200 rows x 4 columns]

# %%
#ReHModel.fit(train_x.drop([0, 2], axis='columns'), train_y, epochs=200)
ReHModel.fit(train_x, train_y, epochs=200)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 0s 1ms/step - loss: 17.5640
# Epoch 2/200
# 7/7 [==============================] - 0s 931us/step - loss: 17.2166
# Epoch 3/200
# 7/7 [==============================] - 0s 1ms/step - loss: 14.4433
# Epoch 4/200
# 7/7 [==============================] - 0s 2ms/step - loss: 13.3394
# Epoch 5/200
# 7/7 [==============================] - 0s 1ms/step - loss: 11.8377
# Epoch 6/200
# 7/7 [==============================] - 0s 1ms/step - loss: 10.8838
# Epoch 7/200
# 7/7 [==============================] - 0s 1ms/step - loss: 10.7066
# Epoch 8/200
# 7/7 [==============================] - 0s 2ms/step - loss: 9.6993
# Epoch 9/200
# 7/7 [==============================] - 0s 1ms/step - loss: 9.2926
# Epoch 10/200
# 7/7 [==============================] - 0s 904us/step - loss: 9.1958
# Epoch 11/200
# 7/7 [==============================] - 0s 1ms/step - loss: 8.6889
# Epoch 12/200
# 7/7 [==============================] - 0s 2ms/step - loss: 8.4059
# Epoch 13/200
# 7/7 [==============================] - 0s 1ms/step - loss: 8.7425
# Epoch 14/200
# 7/7 [==============================] - 0s 1ms/step - loss: 8.4070
# Epoch 15/200
# 7/7 [==============================] - 0s 1ms/step - loss: 7.8197
# Epoch 16/200
# 7/7 [==============================] - 0s 2ms/step - loss: 7.8718
# Epoch 17/200
# 7/7 [==============================] - 0s 2ms/step - loss: 7.6367
# Epoch 18/200
# 7/7 [==============================] - 0s 1ms/step - loss: 7.6180
# Epoch 19/200
# 7/7 [==============================] - 0s 1ms/step - loss: 7.4595
# Epoch 20/200
# 7/7 [==============================] - 0s 1ms/step - loss: 7.7699
# Epoch 21/200
# 7/7 [==============================] - 0s 1ms/step - loss: 9.1992
# Epoch 22/200
# 7/7 [==============================] - 0s 1ms/step - loss: 7.5712
# Epoch 23/200
# 7/7 [==============================] - 0s 1ms/step - loss: 7.2177
# Epoch 24/200
# 7/7 [==============================] - 0s 2ms/step - loss: 7.1952
# Epoch 25/200
# 7/7 [==============================] - 0s 1ms/step - loss: 7.1943
# Epoch 26/200
# 7/7 [==============================] - 0s 1ms/step - loss: 7.4955
# Epoch 27/200
# 7/7 [==============================] - 0s 911us/step - loss: 6.8953
# Epoch 28/200
# 7/7 [==============================] - 0s 2ms/step - loss: 7.0689
# Epoch 29/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.8669
# Epoch 30/200
# 7/7 [==============================] - 0s 841us/step - loss: 6.8991
# Epoch 31/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.6731
# Epoch 32/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.8504
# Epoch 33/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.6524
# Epoch 34/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.5811
# Epoch 35/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.5212
# Epoch 36/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.7414
# Epoch 37/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.8594
# Epoch 38/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.8316
# Epoch 39/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.3868
# Epoch 40/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.2827
# Epoch 41/200
# 7/7 [==============================] - 0s 1ms/step - loss: 7.3606
# Epoch 42/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.9771
# Epoch 43/200
# 7/7 [==============================] - 0s 921us/step - loss: 6.9390
# Epoch 44/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.3014
# Epoch 45/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.3987
# Epoch 46/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.0392
# Epoch 47/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.2660
# Epoch 48/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.0790
# Epoch 49/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.7706
# Epoch 50/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.4821
# Epoch 51/200
# 7/7 [==============================] - 0s 944us/step - loss: 6.4341
# Epoch 52/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.6330
# Epoch 53/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.2592
# Epoch 54/200
# 7/7 [==============================] - 0s 808us/step - loss: 6.2359
# Epoch 55/200
# 7/7 [==============================] - 0s 2ms/step - loss: 6.0306
# Epoch 56/200
# 7/7 [==============================] - 0s 959us/step - loss: 5.7456
# Epoch 57/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.0887
# Epoch 58/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.8313
# Epoch 59/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.7083
# Epoch 60/200
# 7/7 [==============================] - ETA: 0s - loss: 2.714 - 0s 1ms/step - loss: 5.8535
# Epoch 61/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.1513
# Epoch 62/200
# 7/7 [==============================] - 0s 994us/step - loss: 6.2743
# Epoch 63/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.7682
# Epoch 64/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.4360
# Epoch 65/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.0833
# Epoch 66/200
# 7/7 [==============================] - 0s 835us/step - loss: 6.4186
# Epoch 67/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.7466
# Epoch 68/200
# 7/7 [==============================] - 0s 894us/step - loss: 5.6151
# Epoch 69/200
# 7/7 [==============================] - 0s 865us/step - loss: 5.7379
# Epoch 70/200
# 7/7 [==============================] - 0s 875us/step - loss: 5.4598
# Epoch 71/200
# 7/7 [==============================] - 0s 833us/step - loss: 5.4611
# Epoch 72/200
# 7/7 [==============================] - 0s 961us/step - loss: 5.6138
# Epoch 73/200
# 7/7 [==============================] - 0s 895us/step - loss: 6.0351
# Epoch 74/200
# 7/7 [==============================] - 0s 882us/step - loss: 5.3383
# Epoch 75/200
# 7/7 [==============================] - 0s 887us/step - loss: 5.4791
# Epoch 76/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.9447
# Epoch 77/200
# 7/7 [==============================] - 0s 986us/step - loss: 5.6648
# Epoch 78/200
# 7/7 [==============================] - 0s 958us/step - loss: 5.7105
# Epoch 79/200
# 7/7 [==============================] - 0s 1ms/step - loss: 7.2911
# Epoch 80/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.0779
# Epoch 81/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.7178
# Epoch 82/200
# 7/7 [==============================] - 0s 862us/step - loss: 5.5850
# Epoch 83/200
# 7/7 [==============================] - 0s 885us/step - loss: 5.4687
# Epoch 84/200
# 7/7 [==============================] - 0s 970us/step - loss: 5.2455
# Epoch 85/200
# 7/7 [==============================] - 0s 855us/step - loss: 5.9423
# Epoch 86/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.9382
# Epoch 87/200
# 7/7 [==============================] - 0s 920us/step - loss: 5.5838
# Epoch 88/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.3749
# Epoch 89/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.6606
# Epoch 90/200
# 7/7 [==============================] - 0s 976us/step - loss: 5.1642
# Epoch 91/200
# 7/7 [==============================] - 0s 931us/step - loss: 5.1507
# Epoch 92/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.3875
# Epoch 93/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.1772
# Epoch 94/200
# 7/7 [==============================] - 0s 980us/step - loss: 5.9976
# Epoch 95/200
# 7/7 [==============================] - 0s 934us/step - loss: 6.5941
# Epoch 96/200
# 7/7 [==============================] - 0s 2ms/step - loss: 5.8676
# Epoch 97/200
# 7/7 [==============================] - 0s 966us/step - loss: 5.1277
# Epoch 98/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.0162
# Epoch 99/200
# 7/7 [==============================] - 0s 969us/step - loss: 5.4920
# Epoch 100/200
# 7/7 [==============================] - 0s 944us/step - loss: 5.2207
# Epoch 101/200
# 7/7 [==============================] - 0s 862us/step - loss: 5.1311
# Epoch 102/200
# 7/7 [==============================] - 0s 893us/step - loss: 5.4467
# Epoch 103/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.2456
# Epoch 104/200
# 7/7 [==============================] - 0s 896us/step - loss: 5.1124
# Epoch 105/200
# 7/7 [==============================] - 0s 959us/step - loss: 5.3567
# Epoch 106/200
# 7/7 [==============================] - 0s 829us/step - loss: 5.5698
# Epoch 107/200
# 7/7 [==============================] - 0s 929us/step - loss: 4.9229
# Epoch 108/200
# 7/7 [==============================] - 0s 830us/step - loss: 4.9867
# Epoch 109/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.8957
# Epoch 110/200
# 7/7 [==============================] - 0s 810us/step - loss: 4.9765
# Epoch 111/200
# 7/7 [==============================] - 0s 972us/step - loss: 5.0369
# Epoch 112/200
# 7/7 [==============================] - 0s 2ms/step - loss: 5.3723
# Epoch 113/200
# 7/7 [==============================] - 0s 881us/step - loss: 5.4672
# Epoch 114/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.8941
# Epoch 115/200
# 7/7 [==============================] - 0s 865us/step - loss: 7.0384
# Epoch 116/200
# 7/7 [==============================] - 0s 913us/step - loss: 6.1003
# Epoch 117/200
# 7/7 [==============================] - 0s 866us/step - loss: 5.6358
# Epoch 118/200
# 7/7 [==============================] - 0s 935us/step - loss: 6.1746
# Epoch 119/200
# 7/7 [==============================] - 0s 874us/step - loss: 5.0367
# Epoch 120/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.8712
# Epoch 121/200
# 7/7 [==============================] - 0s 927us/step - loss: 5.0097
# Epoch 122/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.8678
# Epoch 123/200
# 7/7 [==============================] - 0s 879us/step - loss: 4.9146
# Epoch 124/200
# 7/7 [==============================] - 0s 957us/step - loss: 5.3786
# Epoch 125/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.1888
# Epoch 126/200
# 7/7 [==============================] - 0s 963us/step - loss: 5.1803
# Epoch 127/200
# 7/7 [==============================] - 0s 963us/step - loss: 6.0920
# Epoch 128/200
# 7/7 [==============================] - 0s 896us/step - loss: 4.9656
# Epoch 129/200
# 7/7 [==============================] - 0s 987us/step - loss: 4.9560
# Epoch 130/200
# 7/7 [==============================] - 0s 932us/step - loss: 5.1069
# Epoch 131/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.9303
# Epoch 132/200
# 7/7 [==============================] - 0s 800us/step - loss: 4.8151
# Epoch 133/200
# 7/7 [==============================] - 0s 925us/step - loss: 4.7779
# Epoch 134/200
# 7/7 [==============================] - 0s 876us/step - loss: 5.3042
# Epoch 135/200
# 7/7 [==============================] - 0s 914us/step - loss: 5.0332
# Epoch 136/200
# 7/7 [==============================] - 0s 803us/step - loss: 5.4665
# Epoch 137/200
# 7/7 [==============================] - 0s 876us/step - loss: 4.9584
# Epoch 138/200
# 7/7 [==============================] - 0s 807us/step - loss: 4.8458
# Epoch 139/200
# 7/7 [==============================] - 0s 949us/step - loss: 4.7628
# Epoch 140/200
# 7/7 [==============================] - 0s 781us/step - loss: 4.9989
# Epoch 141/200
# 7/7 [==============================] - 0s 880us/step - loss: 5.6515
# Epoch 142/200
# 7/7 [==============================] - 0s 778us/step - loss: 7.3261
# Epoch 143/200
# 7/7 [==============================] - 0s 838us/step - loss: 8.0179
# Epoch 144/200
# 7/7 [==============================] - 0s 784us/step - loss: 5.6184
# Epoch 145/200
# 7/7 [==============================] - 0s 895us/step - loss: 4.8555
# Epoch 146/200
# 7/7 [==============================] - 0s 874us/step - loss: 5.0151
# Epoch 147/200
# 7/7 [==============================] - 0s 875us/step - loss: 4.9846
# Epoch 148/200
# 7/7 [==============================] - 0s 841us/step - loss: 4.8005
# Epoch 149/200
# 7/7 [==============================] - 0s 870us/step - loss: 5.4845
# Epoch 150/200
# 7/7 [==============================] - 0s 914us/step - loss: 7.0242
# Epoch 151/200
# 7/7 [==============================] - 0s 923us/step - loss: 5.5072
# Epoch 152/200
# 7/7 [==============================] - 0s 937us/step - loss: 5.4709
# Epoch 153/200
# 7/7 [==============================] - 0s 883us/step - loss: 5.3360
# Epoch 154/200
# 7/7 [==============================] - 0s 973us/step - loss: 5.7283
# Epoch 155/200
# 7/7 [==============================] - 0s 856us/step - loss: 5.5913
# Epoch 156/200
# 7/7 [==============================] - 0s 922us/step - loss: 4.9728
# Epoch 157/200
# 7/7 [==============================] - 0s 844us/step - loss: 4.7971
# Epoch 158/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.8915
# Epoch 159/200
# 7/7 [==============================] - 0s 829us/step - loss: 4.7982
# Epoch 160/200
# 7/7 [==============================] - 0s 845us/step - loss: 4.7569
# Epoch 161/200
# 7/7 [==============================] - 0s 837us/step - loss: 4.9372
# Epoch 162/200
# 7/7 [==============================] - 0s 859us/step - loss: 5.0129
# Epoch 163/200
# 7/7 [==============================] - 0s 942us/step - loss: 6.0690
# Epoch 164/200
# 7/7 [==============================] - 0s 939us/step - loss: 4.9817
# Epoch 165/200
# 7/7 [==============================] - 0s 874us/step - loss: 4.9044
# Epoch 166/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.6501
# Epoch 167/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.1626
# Epoch 168/200
# 7/7 [==============================] - 0s 861us/step - loss: 4.7376
# Epoch 169/200
# 7/7 [==============================] - 0s 959us/step - loss: 5.5028
# Epoch 170/200
# 7/7 [==============================] - 0s 796us/step - loss: 6.6749
# Epoch 171/200
# 7/7 [==============================] - 0s 952us/step - loss: 5.4315
# Epoch 172/200
# 7/7 [==============================] - 0s 796us/step - loss: 4.8091
# Epoch 173/200
# 7/7 [==============================] - 0s 925us/step - loss: 4.9240
# Epoch 174/200
# 7/7 [==============================] - 0s 783us/step - loss: 5.1388
# Epoch 175/200
# 7/7 [==============================] - 0s 895us/step - loss: 5.1902
# Epoch 176/200
# 7/7 [==============================] - 0s 827us/step - loss: 4.7280
# Epoch 177/200
# 7/7 [==============================] - 0s 936us/step - loss: 4.9078
# Epoch 178/200
# 7/7 [==============================] - 0s 820us/step - loss: 4.7883
# Epoch 179/200
# 7/7 [==============================] - 0s 890us/step - loss: 4.7159
# Epoch 180/200
# 7/7 [==============================] - 0s 820us/step - loss: 4.6825
# Epoch 181/200
# 7/7 [==============================] - 0s 872us/step - loss: 4.6737
# Epoch 182/200
# 7/7 [==============================] - 0s 806us/step - loss: 4.7120
# Epoch 183/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.0878
# Epoch 184/200
# 7/7 [==============================] - 0s 891us/step - loss: 4.5667
# Epoch 185/200
# 7/7 [==============================] - 0s 879us/step - loss: 4.7648
# Epoch 186/200
# 7/7 [==============================] - 0s 823us/step - loss: 4.7548
# Epoch 187/200
# 7/7 [==============================] - 0s 994us/step - loss: 4.8774
# Epoch 188/200
# 7/7 [==============================] - 0s 906us/step - loss: 5.3639
# Epoch 189/200
# 7/7 [==============================] - 0s 863us/step - loss: 5.5616
# Epoch 190/200
# 7/7 [==============================] - 0s 865us/step - loss: 5.0300
# Epoch 191/200
# 7/7 [==============================] - 0s 839us/step - loss: 5.6028
# Epoch 192/200
# 7/7 [==============================] - 0s 804us/step - loss: 5.5915
# Epoch 193/200
# 7/7 [==============================] - 0s 882us/step - loss: 4.8060
# Epoch 194/200
# 7/7 [==============================] - 0s 822us/step - loss: 4.7469
# Epoch 195/200
# 7/7 [==============================] - 0s 828us/step - loss: 4.6400
# Epoch 196/200
# 7/7 [==============================] - 0s 839us/step - loss: 5.0750
# Epoch 197/200
# 7/7 [==============================] - 0s 853us/step - loss: 5.1322
# Epoch 198/200
# 7/7 [==============================] - 0s 852us/step - loss: 5.3781
# Epoch 199/200
# 7/7 [==============================] - 0s 945us/step - loss: 5.4342
# Epoch 200/200
# 7/7 [==============================] - 0s 781us/step - loss: 5.0898

# %%
ReHModel.weights
# Out:
# [<tf.Variable 'dense_29/kernel:0' shape=(4, 1) dtype=float32, numpy=
#  array([[  0.07185411],
#         [ -1.2169037 ],
#         [  2.2498546 ],
#         [-14.880165  ]], dtype=float32)>,
#  <tf.Variable 'dense_29/bias:0' shape=(1,) dtype=float32, numpy=array([-0.29529765], dtype=float32)>,
#  <tf.Variable 'dense_30/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[2.942429]], dtype=float32)>,
#  <tf.Variable 'dense_30/bias:0' shape=(1,) dtype=float32, numpy=array([0.713438], dtype=float32)>]

# %%
valid_x
# Out:
#        k       QQ       x_b         t
# 13  7.75  2.17955  0.385579 -0.283318
# 14  7.75  2.63258  0.345012 -0.361188
# 8   5.75  2.03646  0.415563 -0.373495
# 5   5.75  2.17955  0.385579 -0.283318
# 7   5.75  2.07387  0.436939 -0.291599

# %%
valid_y
# Out:
# 13     6.809949
# 14    10.773485
# 8     11.758800
# 5      6.719193
# 7      8.872783
# Name: ReH, dtype: float64

# %%
#np.mean((ReHModel(valid_x.drop(["k", "x_b"], axis='columns')).numpy()[:, 0] - valid_y)**2)
np.mean((ReHModel(valid_x).numpy()[:, 0] - valid_y)**2)
# Out:
# 1.4736239909344535

# %%
#ReHModel(valid_x.drop(["k", "x_b"], axis='columns'))
ReHModel(valid_x)
# Out:
# <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
# array([[ 8.636179],
#        [10.154925],
#        [12.872473],
#        [ 8.213327],
#        [ 9.294309]], dtype=float32)>

# %% [markdown]
# ## With only QQ and t

# %%
kinematics = tf.keras.Input(shape=(2))
x = tf.keras.layers.Dense(1, activation='relu')(kinematics)
outputs = tf.keras.layers.Dense(1)(x)

ReHModel = tf.keras.Model(inputs=kinematics, outputs=outputs, name="GlobalModel")

# %%
ReHModel.compile(optimizer=tf.keras.optimizers.Adam(.1), loss=tf.keras.losses.MeanSquaredError())

# %%
ReHModel.fit(train_x.drop([0, 2], axis='columns'), train_y, epochs=200)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 0s 1ms/step - loss: 103.6929
# Epoch 2/200
# 7/7 [==============================] - 0s 940us/step - loss: 78.4671
# Epoch 3/200
# 7/7 [==============================] - 0s 851us/step - loss: 46.6734
# Epoch 4/200
# 7/7 [==============================] - 0s 1ms/step - loss: 15.4216
# Epoch 5/200
# 7/7 [==============================] - 0s 1ms/step - loss: 17.6828
# Epoch 6/200
# 7/7 [==============================] - 0s 1ms/step - loss: 11.7048
# Epoch 7/200
# 7/7 [==============================] - 0s 1ms/step - loss: 12.2842
# Epoch 8/200
# 7/7 [==============================] - 0s 995us/step - loss: 10.9237
# Epoch 9/200
# 7/7 [==============================] - 0s 1ms/step - loss: 11.6488
# Epoch 10/200
# 7/7 [==============================] - 0s 1ms/step - loss: 11.0772
# Epoch 11/200
# 7/7 [==============================] - 0s 1ms/step - loss: 10.7525
# Epoch 12/200
# 7/7 [==============================] - 0s 1ms/step - loss: 10.7067
# Epoch 13/200
# 7/7 [==============================] - 0s 1ms/step - loss: 10.6670
# Epoch 14/200
# 7/7 [==============================] - 0s 1ms/step - loss: 10.5536
# Epoch 15/200
# 7/7 [==============================] - 0s 1ms/step - loss: 10.5342
# Epoch 16/200
# 7/7 [==============================] - 0s 1ms/step - loss: 10.4794
# Epoch 17/200
# 7/7 [==============================] - 0s 1000us/step - loss: 10.3796
# Epoch 18/200
# 7/7 [==============================] - 0s 1ms/step - loss: 10.4033
# Epoch 19/200
# 7/7 [==============================] - 0s 1ms/step - loss: 10.3029
# Epoch 20/200
# 7/7 [==============================] - 0s 1ms/step - loss: 10.1877
# Epoch 21/200
# 7/7 [==============================] - 0s 960us/step - loss: 10.1467
# Epoch 22/200
# 7/7 [==============================] - 0s 1ms/step - loss: 10.0231
# Epoch 23/200
# 7/7 [==============================] - 0s 877us/step - loss: 10.0316
# Epoch 24/200
# 7/7 [==============================] - 0s 1ms/step - loss: 10.0135
# Epoch 25/200
# 7/7 [==============================] - 0s 1ms/step - loss: 9.9215
# Epoch 26/200
# 7/7 [==============================] - 0s 1ms/step - loss: 9.9389
# Epoch 27/200
# 7/7 [==============================] - 0s 1ms/step - loss: 9.8104
# Epoch 28/200
# 7/7 [==============================] - 0s 1ms/step - loss: 9.7359
# Epoch 29/200
# 7/7 [==============================] - 0s 1ms/step - loss: 9.7065
# Epoch 30/200
# 7/7 [==============================] - 0s 1ms/step - loss: 9.7553
# Epoch 31/200
# 7/7 [==============================] - 0s 1ms/step - loss: 9.5980
# Epoch 32/200
# 7/7 [==============================] - 0s 963us/step - loss: 9.4476
# Epoch 33/200
# 7/7 [==============================] - 0s 1ms/step - loss: 9.4789
# Epoch 34/200
# 7/7 [==============================] - 0s 1ms/step - loss: 9.3190
# Epoch 35/200
# 7/7 [==============================] - 0s 1ms/step - loss: 9.2198
# Epoch 36/200
# 7/7 [==============================] - 0s 863us/step - loss: 9.0958
# Epoch 37/200
# 7/7 [==============================] - 0s 1ms/step - loss: 9.0507
# Epoch 38/200
# 7/7 [==============================] - 0s 1ms/step - loss: 9.0214
# Epoch 39/200
# 7/7 [==============================] - 0s 1ms/step - loss: 8.8957
# Epoch 40/200
# 7/7 [==============================] - 0s 827us/step - loss: 8.7336
# Epoch 41/200
# 7/7 [==============================] - 0s 1ms/step - loss: 8.7687
# Epoch 42/200
# 7/7 [==============================] - 0s 1ms/step - loss: 8.6411
# Epoch 43/200
# 7/7 [==============================] - 0s 1ms/step - loss: 8.4410
# Epoch 44/200
# 7/7 [==============================] - 0s 2ms/step - loss: 8.4530
# Epoch 45/200
# 7/7 [==============================] - 0s 824us/step - loss: 8.1397
# Epoch 46/200
# 7/7 [==============================] - 0s 1ms/step - loss: 8.3760
# Epoch 47/200
# 7/7 [==============================] - 0s 830us/step - loss: 7.8926
# Epoch 48/200
# 7/7 [==============================] - 0s 1ms/step - loss: 7.8535
# Epoch 49/200
# 7/7 [==============================] - 0s 939us/step - loss: 7.6911
# Epoch 50/200
# 7/7 [==============================] - 0s 854us/step - loss: 7.6475
# Epoch 51/200
# 7/7 [==============================] - 0s 980us/step - loss: 7.4307
# Epoch 52/200
# 7/7 [==============================] - 0s 829us/step - loss: 7.1490
# Epoch 53/200
# 7/7 [==============================] - 0s 888us/step - loss: 7.1972
# Epoch 54/200
# 7/7 [==============================] - 0s 972us/step - loss: 6.9283
# Epoch 55/200
# 7/7 [==============================] - 0s 997us/step - loss: 6.7094
# Epoch 56/200
# 7/7 [==============================] - 0s 839us/step - loss: 6.6134
# Epoch 57/200
# 7/7 [==============================] - 0s 989us/step - loss: 6.5747
# Epoch 58/200
# 7/7 [==============================] - 0s 856us/step - loss: 6.3074
# Epoch 59/200
# 7/7 [==============================] - 0s 1ms/step - loss: 6.5540
# Epoch 60/200
# 7/7 [==============================] - 0s 914us/step - loss: 6.0688
# Epoch 61/200
# 7/7 [==============================] - 0s 915us/step - loss: 5.9141
# Epoch 62/200
# 7/7 [==============================] - 0s 889us/step - loss: 5.8417
# Epoch 63/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.8033
# Epoch 64/200
# 7/7 [==============================] - 0s 964us/step - loss: 5.6643
# Epoch 65/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.6264
# Epoch 66/200
# 7/7 [==============================] - 0s 2ms/step - loss: 5.6312
# Epoch 67/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.6074
# Epoch 68/200
# 7/7 [==============================] - 0s 904us/step - loss: 5.6931
# Epoch 69/200
# 7/7 [==============================] - 0s 886us/step - loss: 5.4155
# Epoch 70/200
# 7/7 [==============================] - 0s 884us/step - loss: 5.7423
# Epoch 71/200
# 7/7 [==============================] - 0s 946us/step - loss: 5.3063
# Epoch 72/200
# 7/7 [==============================] - 0s 967us/step - loss: 5.2012
# Epoch 73/200
# 7/7 [==============================] - 0s 996us/step - loss: 5.2291
# Epoch 74/200
# 7/7 [==============================] - 0s 893us/step - loss: 5.1720
# Epoch 75/200
# 7/7 [==============================] - 0s 874us/step - loss: 5.1873
# Epoch 76/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.2188
# Epoch 77/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.3976
# Epoch 78/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.0075
# Epoch 79/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.0257
# Epoch 80/200
# 7/7 [==============================] - 0s 910us/step - loss: 5.1052
# Epoch 81/200
# 7/7 [==============================] - 0s 949us/step - loss: 5.2706
# Epoch 82/200
# 7/7 [==============================] - 0s 918us/step - loss: 5.3311
# Epoch 83/200
# 7/7 [==============================] - 0s 2ms/step - loss: 5.1438
# Epoch 84/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.8489
# Epoch 85/200
# 7/7 [==============================] - 0s 924us/step - loss: 5.0951
# Epoch 86/200
# 7/7 [==============================] - 0s 934us/step - loss: 5.1261
# Epoch 87/200
# 7/7 [==============================] - 0s 848us/step - loss: 5.3450
# Epoch 88/200
# 7/7 [==============================] - 0s 875us/step - loss: 5.0003
# Epoch 89/200
# 7/7 [==============================] - 0s 886us/step - loss: 5.1923
# Epoch 90/200
# 7/7 [==============================] - 0s 868us/step - loss: 5.3984
# Epoch 91/200
# 7/7 [==============================] - 0s 905us/step - loss: 5.7002
# Epoch 92/200
# 7/7 [==============================] - 0s 909us/step - loss: 4.7884
# Epoch 93/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.8539
# Epoch 94/200
# 7/7 [==============================] - 0s 899us/step - loss: 5.4025
# Epoch 95/200
# 7/7 [==============================] - 0s 914us/step - loss: 5.3024
# Epoch 96/200
# 7/7 [==============================] - 0s 870us/step - loss: 4.9733
# Epoch 97/200
# 7/7 [==============================] - 0s 901us/step - loss: 4.8355
# Epoch 98/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.8502
# Epoch 99/200
# 7/7 [==============================] - 0s 860us/step - loss: 5.1260
# Epoch 100/200
# 7/7 [==============================] - 0s 1000us/step - loss: 5.0222
# Epoch 101/200
# 7/7 [==============================] - 0s 978us/step - loss: 4.8140
# Epoch 102/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.7449
# Epoch 103/200
# 7/7 [==============================] - 0s 976us/step - loss: 4.8482
# Epoch 104/200
# 7/7 [==============================] - 0s 904us/step - loss: 5.0918
# Epoch 105/200
# 7/7 [==============================] - 0s 988us/step - loss: 5.1939
# Epoch 106/200
# 7/7 [==============================] - 0s 943us/step - loss: 5.0829
# Epoch 107/200
# 7/7 [==============================] - 0s 896us/step - loss: 4.8886
# Epoch 108/200
# 7/7 [==============================] - 0s 845us/step - loss: 4.8725
# Epoch 109/200
# 7/7 [==============================] - 0s 921us/step - loss: 4.9633
# Epoch 110/200
# 7/7 [==============================] - 0s 843us/step - loss: 4.7566
# Epoch 111/200
# 7/7 [==============================] - 0s 896us/step - loss: 4.7328
# Epoch 112/200
# 7/7 [==============================] - 0s 930us/step - loss: 4.7236
# Epoch 113/200
# 7/7 [==============================] - 0s 892us/step - loss: 4.8417
# Epoch 114/200
# 7/7 [==============================] - 0s 926us/step - loss: 4.7853
# Epoch 115/200
# 7/7 [==============================] - 0s 944us/step - loss: 4.7813
# Epoch 116/200
# 7/7 [==============================] - 0s 874us/step - loss: 4.6665
# Epoch 117/200
# 7/7 [==============================] - 0s 885us/step - loss: 4.7647
# Epoch 118/200
# 7/7 [==============================] - 0s 826us/step - loss: 4.7629
# Epoch 119/200
# 7/7 [==============================] - 0s 871us/step - loss: 4.8678
# Epoch 120/200
# 7/7 [==============================] - 0s 853us/step - loss: 4.6784
# Epoch 121/200
# 7/7 [==============================] - 0s 848us/step - loss: 4.7351
# Epoch 122/200
# 7/7 [==============================] - 0s 874us/step - loss: 4.9532
# Epoch 123/200
# 7/7 [==============================] - 0s 838us/step - loss: 4.7562
# Epoch 124/200
# 7/7 [==============================] - 0s 924us/step - loss: 4.7072
# Epoch 125/200
# 7/7 [==============================] - 0s 814us/step - loss: 4.7203
# Epoch 126/200
# 7/7 [==============================] - 0s 869us/step - loss: 4.8351
# Epoch 127/200
# 7/7 [==============================] - 0s 880us/step - loss: 4.9402
# Epoch 128/200
# 7/7 [==============================] - 0s 867us/step - loss: 5.0217
# Epoch 129/200
# 7/7 [==============================] - 0s 942us/step - loss: 5.1088
# Epoch 130/200
# 7/7 [==============================] - 0s 831us/step - loss: 4.7616
# Epoch 131/200
# 7/7 [==============================] - 0s 849us/step - loss: 4.9504
# Epoch 132/200
# 7/7 [==============================] - 0s 902us/step - loss: 4.8033
# Epoch 133/200
# 7/7 [==============================] - 0s 906us/step - loss: 4.6746
# Epoch 134/200
# 7/7 [==============================] - 0s 884us/step - loss: 4.5920
# Epoch 135/200
# 7/7 [==============================] - 0s 934us/step - loss: 4.8863
# Epoch 136/200
# 7/7 [==============================] - 0s 887us/step - loss: 5.4236
# Epoch 137/200
# 7/7 [==============================] - 0s 964us/step - loss: 4.8011
# Epoch 138/200
# 7/7 [==============================] - 0s 920us/step - loss: 5.5401
# Epoch 139/200
# 7/7 [==============================] - 0s 992us/step - loss: 4.7693
# Epoch 140/200
# 7/7 [==============================] - 0s 892us/step - loss: 4.7192
# Epoch 141/200
# 7/7 [==============================] - 0s 937us/step - loss: 4.7281
# Epoch 142/200
# 7/7 [==============================] - 0s 785us/step - loss: 4.6676
# Epoch 143/200
# 7/7 [==============================] - 0s 918us/step - loss: 4.7907
# Epoch 144/200
# 7/7 [==============================] - 0s 826us/step - loss: 4.7269
# Epoch 145/200
# 7/7 [==============================] - 0s 921us/step - loss: 4.7294
# Epoch 146/200
# 7/7 [==============================] - 0s 852us/step - loss: 4.7730
# Epoch 147/200
# 7/7 [==============================] - 0s 3ms/step - loss: 4.6753
# Epoch 148/200
# 7/7 [==============================] - 0s 824us/step - loss: 4.6423
# Epoch 149/200
# 7/7 [==============================] - 0s 898us/step - loss: 4.7155
# Epoch 150/200
# 7/7 [==============================] - 0s 902us/step - loss: 4.9536
# Epoch 151/200
# 7/7 [==============================] - 0s 936us/step - loss: 4.8856
# Epoch 152/200
# 7/7 [==============================] - 0s 987us/step - loss: 4.7459
# Epoch 153/200
# 7/7 [==============================] - 0s 874us/step - loss: 4.9171
# Epoch 154/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.9482
# Epoch 155/200
# 7/7 [==============================] - 0s 836us/step - loss: 5.1202
# Epoch 156/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.0194
# Epoch 157/200
# 7/7 [==============================] - 0s 848us/step - loss: 5.0602
# Epoch 158/200
# 7/7 [==============================] - 0s 976us/step - loss: 5.3315
# Epoch 159/200
# 7/7 [==============================] - 0s 859us/step - loss: 4.6786
# Epoch 160/200
# 7/7 [==============================] - 0s 857us/step - loss: 4.8370
# Epoch 161/200
# 7/7 [==============================] - 0s 885us/step - loss: 4.6638
# Epoch 162/200
# 7/7 [==============================] - 0s 937us/step - loss: 4.7847
# Epoch 163/200
# 7/7 [==============================] - 0s 872us/step - loss: 5.3729
# Epoch 164/200
# 7/7 [==============================] - 0s 883us/step - loss: 5.0481
# Epoch 165/200
# 7/7 [==============================] - 0s 906us/step - loss: 4.6933
# Epoch 166/200
# 7/7 [==============================] - 0s 840us/step - loss: 4.8235
# Epoch 167/200
# 7/7 [==============================] - 0s 821us/step - loss: 4.9411
# Epoch 168/200
# 7/7 [==============================] - 0s 891us/step - loss: 5.1671
# Epoch 169/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.7437
# Epoch 170/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.7417
# Epoch 171/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.7057
# Epoch 172/200
# 7/7 [==============================] - 0s 2ms/step - loss: 4.6835
# Epoch 173/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.8613
# Epoch 174/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.9968
# Epoch 175/200
# 7/7 [==============================] - 0s 1ms/step - loss: 4.9792
# Epoch 176/200
# 7/7 [==============================] - 0s 957us/step - loss: 4.7403
# Epoch 177/200
# 7/7 [==============================] - 0s 947us/step - loss: 4.9071
# Epoch 178/200
# 7/7 [==============================] - 0s 853us/step - loss: 4.7822
# Epoch 179/200
# 7/7 [==============================] - 0s 1ms/step - loss: 5.3496
# Epoch 180/200
# 7/7 [==============================] - 0s 835us/step - loss: 5.0700
# Epoch 181/200
# 7/7 [==============================] - 0s 925us/step - loss: 4.6590
# Epoch 182/200
# 7/7 [==============================] - 0s 849us/step - loss: 4.8635
# Epoch 183/200
# 7/7 [==============================] - 0s 855us/step - loss: 5.2902
# Epoch 184/200
# 7/7 [==============================] - 0s 877us/step - loss: 4.6772
# Epoch 185/200
# 7/7 [==============================] - 0s 856us/step - loss: 4.6540
# Epoch 186/200
# 7/7 [==============================] - 0s 803us/step - loss: 4.7147
# Epoch 187/200
# 7/7 [==============================] - 0s 903us/step - loss: 4.7439
# Epoch 188/200
# 7/7 [==============================] - 0s 856us/step - loss: 4.7725
# Epoch 189/200
# 7/7 [==============================] - 0s 844us/step - loss: 4.9237
# Epoch 190/200
# 7/7 [==============================] - 0s 839us/step - loss: 5.1726
# Epoch 191/200
# 7/7 [==============================] - 0s 935us/step - loss: 5.2307
# Epoch 192/200
# 7/7 [==============================] - 0s 837us/step - loss: 5.4604
# Epoch 193/200
# 7/7 [==============================] - 0s 947us/step - loss: 4.6606
# Epoch 194/200
# 7/7 [==============================] - 0s 806us/step - loss: 4.9990
# Epoch 195/200
# 7/7 [==============================] - 0s 828us/step - loss: 4.6942
# Epoch 196/200
# 7/7 [==============================] - 0s 805us/step - loss: 5.0918
# Epoch 197/200
# 7/7 [==============================] - 0s 847us/step - loss: 4.6937
# Epoch 198/200
# 7/7 [==============================] - 0s 852us/step - loss: 4.6755
# Epoch 199/200
# 7/7 [==============================] - 0s 820us/step - loss: 4.6811
# Epoch 200/200
# 7/7 [==============================] - 0s 786us/step - loss: 4.6708

# %%
np.mean((ReHModel(valid_x.drop(["k", "x_b"], axis='columns')).numpy()[:, 0] - valid_y)**2)
# Out:
# 0.7736099979173463

# %%
ReHModel(valid_x.drop(["k", "x_b"], axis='columns'))
# Out:
# <tf.Tensor: shape=(5, 1), dtype=float32, numpy=
# array([[ 7.250562],
#        [ 9.148408],
#        [11.995115],
#        [ 7.250562],
#        [ 8.039215]], dtype=float32)>

# %% [markdown]
# Mean absolute percent error

# %%
np.mean(np.abs((valid_y - ReHModel(valid_x.drop(["k", "x_b"], axis='columns')).numpy()[:,0])/valid_y))
# Out:
# 0.08173352818435002

# %% [markdown]
# ## All kinematics for all cffs

# %%
kinematics = tf.keras.Input(shape=(4))
x = tf.keras.layers.Dense(1, activation='relu')(kinematics)
outputs = tf.keras.layers.Dense(1)(kinematics)

cffModel = tf.keras.Model(inputs=kinematics, outputs=outputs, name="GlobalModel")

# %%
cffModel.compile(optimizer=tf.keras.optimizers.Adam(3), loss=tf.keras.losses.MeanSquaredError())

# %%
reh = tf.keras.models.clone_model(cffModel)
ree = tf.keras.models.clone_model(cffModel)
reht = tf.keras.models.clone_model(cffModel)
cffModels = [reh, ree, reht]

# %%
names = ["ReH", "ReE", "ReHTilde"]
for i in range(3):
    valid_y = fits[names[i]].sample(5)
    valid_x = data.getAllKins().reset_index().loc[valid_y.index].drop(["index"], axis='columns')

    train_x = data.getAllKins().reset_index().drop(["index"], axis='columns').drop(valid_x.index, axis='rows')
    train_x = pd.DataFrame(np.repeat(train_x.values, 20, axis=0))

    train_y = np.array([])
    for row in range(15):
        if not row in valid_x.index:
            train_y = np.concatenate((train_y, np.random.normal(fits.loc[row, names[i]],
                                                                fits.loc[row, names[i] + "err"], 20)))
    cffModels[i].compile(optimizer=tf.keras.optimizers.Adam(.1), loss=tf.keras.losses.MeanSquaredError())
    #cffModels[i].fit(train_x.drop([0, 2], axis='columns'), train_y, epochs=200, verbose=0)
    cffModels[i].fit(train_x, train_y, epochs=1000, verbose=0)
    
    print(names[i] + ":")
    #print(cffModels[i](valid_x.drop(["k", "x_b"], axis='columns')))
    print(cffModels[i](valid_x))
    print("Mean absolute pct error:")
    #print(np.mean(np.abs((valid_y - cffModels[i](valid_x.drop(["k", "x_b"], axis='columns')).numpy()[:,0])/valid_y)))
    print(np.mean(np.abs((valid_y - cffModels[i](valid_x).numpy()[:,0])/valid_y)))
    print("\n")
# Out:
# ReH:
# tf.Tensor(
# [[12.529621 ]
#  [ 7.446174 ]
#  [ 7.2702117]
#  [10.864798 ]
#  [ 7.4433093]], shape=(5, 1), dtype=float32)
# Mean absolute pct error:
# 0.10784508043678073
#
#
# ReE:
# tf.Tensor(
# [[-53.221107]
#  [-48.02896 ]
#  [-47.889496]
#  [-45.116707]
#  [-47.113403]], shape=(5, 1), dtype=float32)
# Mean absolute pct error:
# 0.07766827303997292
#
#
# ReHTilde:
# tf.Tensor(
# [[3.793664 ]
#  [4.0030546]
#  [4.2661314]
#  [7.0023346]
#  [7.211725 ]], shape=(5, 1), dtype=float32)
# Mean absolute pct error:
# 0.07943223417405403
