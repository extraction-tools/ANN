# %%
import utilities as uts #general utilities that are useful for all methods
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("dvcs_xs_newsets_genCFFs.csv")
data = uts.DvcsData(df)

#Get real CFF values for Kinematic Sets Chosen
def getRealValues(sets, numPhi = 36):
    realValues = []
    for s in sets: 
        ReH, ReE, ReHtilde = df.loc[numPhi * s, 'ReH': 'ReHtilde']
        realValues.append([ReH, ReE, ReHtilde])

    return realValues

#Calculates mean and std of distribution from model
def calcMeanAndStd(data):
    #print([round(np.mean(data.ReH), 4), round(np.mean(data.ReE), 4), round(np.mean(data.ReHtilde), 4)], [round(np.std(data.ReH), 4), round(np.std(data.ReE), 4), round(np.std(data.ReHtilde), 4)])
    return [[round(np.mean(data.ReH), 4), round(np.mean(data.ReE), 4), round(np.mean(data.ReHtilde), 4)], [round(np.std(data.ReH), 4), round(np.std(data.ReE), 4), round(np.std(data.ReHtilde), 4)]]

#Plots histogram with distribution and real values for a certain kinematic set
def plotHis(data, realValues, setNum, sameAxes = True):
    plt.hist(data.ReH)
    plt.hist(data.ReE)
    plt.hist(data.ReHtilde)

    plt.legend(["ReH", "ReE", "ReHtilde"])
    plt.title(str(setNum) + " Distribution")

    if sameAxes: 
        plt.xlim(xmin=-70, xmax = 20)    
    
    plt.axvline(x=realValues[0], ymin=0, ymax=500)
    plt.axvline(x=realValues[1], ymin=0, ymax=500)
    plt.axvline(x=realValues[2], ymin=0, ymax=500)

sets = [0, 1, 2, 3]
realValues = getRealValues(sets, numPhi=36)

# %% [markdown]
# # Experimental Consistency (15 Models with 40 Learning Iterations, 20 models to average for weights)

# %%
setNum = 0

_ = pd.read_csv("Predictions\Exp" + str(20) + "_" + str(1000) +  "-0-0.csv")
print(realValues[setNum])
plotHis(_, realValues[setNum], setNum)
calcMeanAndStd(_)
# Out:
# [13.0554, -53.0554, 7.25302]
# [13.751, -56.6846, 7.1223] [0.8195, 4.1995, 0.6544]

# %%
_ = pd.read_csv("Predictions\Exp" + str(20) + "_" + str(1000) +  "-1-0.csv")
print(realValues[setNum])
plotHis(_, realValues[setNum], setNum)
calcMeanAndStd(_)
# Out:
# [13.0554, -53.0554, 7.25302]
# [13.3945, -54.8574, 7.173] [1.0684, 5.4752, 0.7031]

# %%
_ = pd.read_csv("Predictions\Exp" + str(20) + "_" + str(1000) +  "-2-0.csv")
print(realValues[setNum])
plotHis(_, realValues[setNum], setNum)
calcMeanAndStd(_)
# Out:
# [13.0554, -53.0554, 7.25302]
# [13.9648, -57.7726, 7.1457] [0.441, 2.2308, 0.6712]

# %%
_ = pd.read_csv("Predictions\Exp" + str(20) + "_" + str(1000) +  "-3-0.csv")
print(realValues[setNum])
plotHis(_, realValues[setNum], setNum)
calcMeanAndStd(_)
# Out:
# [13.0554, -53.0554, 7.25302]
# [14.4357, -60.2154, 7.0375] [0.7951, 4.1056, 0.6565]

# %%
_ = pd.read_csv("Predictions\Exp" + str(20) + "_" + str(1000) +  "-4-0.csv")
print(realValues[setNum])
plotHis(_, realValues[setNum], setNum)
calcMeanAndStd(_)
# Out:
# [13.0554, -53.0554, 7.25302]
# [14.1836, -58.9104, 7.0852] [0.2587, 1.2353, 0.703]

# %%
_ = pd.read_csv("Predictions\Exp" + str(20) + "_" + str(1000) +  "-5-0.csv")
print(realValues[setNum])
plotHis(_, realValues[setNum], setNum)
calcMeanAndStd(_)
# Out:
# [13.0554, -53.0554, 7.25302]
# [13.7389, -56.6269, 7.1238] [0.6824, 3.4859, 0.6715]

# %%
_ = pd.read_csv("Predictions\Exp" + str(20) + "_" + str(1000) +  "-6-0.csv")
print(realValues[setNum])
plotHis(_, realValues[setNum], setNum)
calcMeanAndStd(_)
# Out:
# [13.0554, -53.0554, 7.25302]
# [[14.3888, -59.9829, 7.0782], [0.2765, 1.3318, 0.6755]]

# %%
_ = pd.read_csv("Predictions\Exp" + str(20) + "_" + str(1000) +  "-7-0.csv")
print(realValues[setNum])
plotHis(_, realValues[setNum], setNum)
calcMeanAndStd(_)
# Out:
# [13.0554, -53.0554, 7.25302]
# [[14.2678, -59.3492, 7.0563], [0.5339, 2.6821, 0.6775]]

# %%
_ = pd.read_csv("Predictions\Exp" + str(20) + "_" + str(1000) +  "-8-0.csv")
print(realValues[setNum])
plotHis(_, realValues[setNum], setNum)
calcMeanAndStd(_)
# Out:
# [13.0554, -53.0554, 7.25302]
# [[13.5264, -55.5278, 7.1941], [0.8284, 4.2391, 0.6878]]

# %%
_ = pd.read_csv("Predictions\Exp" + str(20) + "_" + str(1000) +  "-9-0.csv")
print(realValues[setNum])
plotHis(_, realValues[setNum], setNum)
calcMeanAndStd(_)
# Out:
# [13.0554, -53.0554, 7.25302]
# [[13.818, -57.0315, 7.1088], [0.2727, 1.3012, 0.7081]]

# %%
_ = pd.read_csv("Predictions\Exp" + str(20) + "_" + str(1000) +  "-10-0.csv")
print(realValues[setNum])
plotHis(_, realValues[setNum], setNum)
calcMeanAndStd(_)
# Out:
# [13.0554, -53.0554, 7.25302]
# [[13.6831, -56.3575, 7.1465], [0.6399, 3.2133, 0.6771]]

# %% [markdown]
# # Creating Data Table with All Distributions and Spreads

# %%
def getStats():
    means = []
    stds = []

    for i in range(13):
        _ = pd.read_csv("Predictions\Exp" + str(i) + ".csv")
        m, s = calcMeanAndStd(_)
        means.append(m)
        stds.append(s)

    ReH_mean = np.mean((np.asarray(means)[:, 0]))
    ReE_mean = np.mean((np.asarray(means)[:, 1]))
    ReHtilde_mean = np.mean((np.asarray(means)[:, 2]))

    ReH_std = np.std((np.asarray(means)[:, 0]))
    ReE_std = np.std((np.asarray(means)[:, 1]))
    ReHtilde_std = np.std((np.asarray(means)[:, 2]))

    ReH_stdmean = np.mean((np.asarray(stds)[:, 0]))
    ReE_stdmean = np.mean((np.asarray(stds)[:, 1]))
    ReHtilde_stdmean = np.mean((np.asarray(stds)[:, 2]))

    print("Reals: " + str(realValues[setNum]))

    print("Mean of the Means: ")
    print(ReH_mean, ReE_mean, ReHtilde_mean)
    print("Deviations between the Means: ")
    print(ReH_std, ReE_std, ReHtilde_std)

    print("Mean of Standard Deviations: ")
    print(ReH_stdmean, ReE_stdmean, ReHtilde_stdmean)

# %% [markdown]
# Experimental Method Consistency

# %%
meansAverage = np.mean(means)
stdsAverage = np.mean(stds)

# %%
ReH_mean = np.mean((np.asarray(means)[:, 0]))
ReE_mean = np.mean((np.asarray(means)[:, 1]))
ReHtilde_mean = np.mean((np.asarray(means)[:, 2]))

ReH_std = np.std((np.asarray(means)[:, 0]))
ReE_std = np.std((np.asarray(means)[:, 1]))
ReHtilde_std = np.std((np.asarray(means)[:, 2]))

ReH_stdmean = np.mean((np.asarray(stds)[:, 0]))
ReE_stdmean = np.mean((np.asarray(stds)[:, 1]))
ReHtilde_stdmean = np.mean((np.asarray(stds)[:, 2]))

# %%
print("Reals: " + str(realValues[setNum]))


print(ReH_mean, ReE_mean, ReHtilde_mean)
print(ReH_std, ReE_std, ReHtilde_std)
# Out:
# Reals: [13.0554, -53.0554, 7.25302]
# 13.892873333333334 -57.41602666666667 7.119453333333334
# 0.315976535978368 1.6286399235626714 0.04489525389417264

# %%
print(ReH_stdmean, ReE_stdmean, ReHtilde_stdmean)
# Out:
# 0.6422066666666667 3.2574133333333335 0.6795733333333334

# %% [markdown]
# Experimental Method

# %%
setNum = 0
getStats()
# Out:
# Reals: [13.0554, -53.0554, 7.25302]
# Mean of the Means:
# 13.871546153846152 -57.308800000000005 7.135892307692308
# Deviations between the Means:
# 0.2887758636179344 1.4868494916329735 0.028580317636671217
# Mean of Standard Deviations:
# 0.3750538461538462 1.8188692307692305 0.686046153846154

# %% [markdown]
# Method2 Consistency

# %%
setNum = 0
getStats()
# Out:
# Reals: [13.0554, -53.0554, 7.25302]
# Mean of the Means:
# 13.839028571428573 -57.12170714285714 7.116771428571428
# Deviations between the Means:
# 0.04881506542292957 0.24412030835016474 0.024277809637945687
# Mean of Standard Deviations:
# 1.0430785714285713 5.337049999999999 0.6847000000000002

# %% [markdown]
# PureBootrapping

# %%
setNum = 0
getStats()
# Out:
# Reals: [13.0554, -53.0554, 7.25302]
# Mean of the Means:
# 6.182364285714286 -17.770014285714286 7.719714285714285
# Deviations between the Means:
# 0.02254502184971395 0.09992967425103653 0.028765427094315225
# Mean of Standard Deviations:
# 0.4215571428571429 2.072885714285715 0.69785
