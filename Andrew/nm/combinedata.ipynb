# %%
from os import listdir
from os.path import isfile, join
import pandas as pd

# %%
path = "Results"+"/"
onlyfiles = [f for f in listdir(path) if isfile(join(path, f))]
df = pd.DataFrame()
for file in onlyfiles:
    cff = pd.read_csv(path+file)
    df = df.append(cff)

# %%
means = pd.DataFrame()
for x in df['set'].unique():
    arr = df[df['set']==x]
    for i in arr['replica'].unique():
        s = arr[arr['replica']==i]
        s = s.mean()
        means = means.append(s, ignore_index=True)
means = means[['set','replica','ReH','ReE','ReHT']]

# %%
means.to_csv('combinedresults.csv')

# %%
means
# Out:
#        set  replica       ReH       ReE      ReHT
# 0      0.0      0.0  3.175411  1.398695 -3.067816
# 1      0.0      1.0  0.348898 -0.189023  5.920924
# 2      0.0      2.0  1.329326  2.450621  2.750407
# 3      0.0      3.0  0.577287  1.112958  5.134810
# 4      0.0      4.0  0.431839  1.184160  5.595391
# ...    ...      ...       ...       ...       ...
# 10095  9.0     95.0  1.855871  0.815372  0.488253
# 10096  9.0     96.0  2.335552 -1.497460 -1.065426
# 10097  9.0     97.0  2.706755  0.350915 -3.365537
# 10098  9.0     98.0 -0.730601  2.700641 -5.485091
# 10099  9.0     99.0  2.448567 -2.141968 -1.552195
#
# [10100 rows x 5 columns]
