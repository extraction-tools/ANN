# %%
run localfit_v2.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /sfs/qumulo/qhome/mag4ka/Baseline/BKM02-tf/localfit_v2.py in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from BHDVCS_tf import TotalFLayer
#       4 from BHDVCS_tf import DvcsData
#       5 from BHDVCS_tf import cffs_from_globalModel
#
# /sfs/qumulo/qhome/mag4ka/Baseline/BKM02-tf/BHDVCS_tf.py in <module>
# ----> 1 import tensorflow as tf
#       2 import numpy as np
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#       5
#
# ModuleNotFoundError: No module named 'tensorflow'
