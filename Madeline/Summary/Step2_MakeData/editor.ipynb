# %% [markdown]
# ## Editing the .csv (Not necessary for all files)
#
# Headers are different depending on whose code you use

# %%
import pandas as pd
df = pd.read_csv("/home/mag4ka/Aaryan/dvcs_bkm_xs_June2021_4pars.csv")

# %%
new_df = df.copy()

# %%
print(new_df)
# Out:
#        #Set  index     k       QQ       x_b         t  phi_x         F  errF  \
# 0         1      0  2.75  1.20485  0.571359 -0.537906      8  0.607496     0
# 1         1      1  2.75  1.20485  0.571359 -0.537906     16  0.542289     0
# 2         1      2  2.75  1.20485  0.571359 -0.537906     24  0.456229     0
# 3         1      3  2.75  1.20485  0.571359 -0.537906     32  0.368314     0
# 4         1      4  2.75  1.20485  0.571359 -0.537906     40  0.290248     0
# ...     ...    ...   ...      ...       ...       ...    ...       ...   ...
# 18130   403     40  2.75  1.87404  0.539747 -0.573392    328  0.175366     0
# 18131   403     41  2.75  1.87404  0.539747 -0.573392    336  0.222574     0
# 18132   403     42  2.75  1.87404  0.539747 -0.573392    344  0.272313     0
# 18133   403     43  2.75  1.87404  0.539747 -0.573392    352  0.312753     0
# 18134   403     44  2.75  1.87404  0.539747 -0.573392    360  0.328722     0
#
# ...

# %%
# new_df = new_df.rename(columns={"gReH": "ReH", "gReE": "ReE", "gReHTilde": "ReHtilde", "sigmaF": "errF"})
new_df = new_df.rename(columns={"errF" : "sigmaF"})

# %%
print(new_df)
# Out:
#        #Set  index     k       QQ       x_b         t  phi_x         F  \
# 0         1      0  2.75  1.20485  0.571359 -0.537906      8  0.607496
# 1         1      1  2.75  1.20485  0.571359 -0.537906     16  0.542289
# 2         1      2  2.75  1.20485  0.571359 -0.537906     24  0.456229
# 3         1      3  2.75  1.20485  0.571359 -0.537906     32  0.368314
# 4         1      4  2.75  1.20485  0.571359 -0.537906     40  0.290248
# ...     ...    ...   ...      ...       ...       ...    ...       ...
# 18130   403     40  2.75  1.87404  0.539747 -0.573392    328  0.175366
# 18131   403     41  2.75  1.87404  0.539747 -0.573392    336  0.222574
# 18132   403     42  2.75  1.87404  0.539747 -0.573392    344  0.272313
# 18133   403     43  2.75  1.87404  0.539747 -0.573392    352  0.312753
# 18134   403     44  2.75  1.87404  0.539747 -0.573392    360  0.328722
#
#        sigmaF  varF  ...  gReHTilde      ReH         e_ReH      ReE  \
# ...

# %%
new_df.to_csv('/home/mag4ka/Aaryan/dvcs_bkm_xs_June2021_4pars_new.csv')
